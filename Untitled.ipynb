# %%
import numpy as np
import pandas as pd 


import os
for dirname, _, filenames in os.walk('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_1.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_10.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_2.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_3.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_4.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_5.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_6.JPG
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_7.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_8.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\apple\Image_9.jpg
# C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data\test\banana\Image_1.jpg
# ...

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
print(tf.__version__)
# Out:
# 2.17.0

# %%
# Create a list with the filepaths for training and testing
train_dir = Path('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data/train')
train_filepaths = list(train_dir.glob(r'**/*.jpg'))

# %%
test_dir = Path('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data/test')
test_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
val_dir = Path('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data/validation')
val_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
import os
from pathlib import Path
import pandas as pd

def image_processing(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures """

    labels = [Path(f).parent.name for f in filepath]  # This gets the folder name (label)
    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop=True)

    return df

# %%
train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)

# %%
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')
# Out:
# -- Training set --
#
# Number of pictures: 2855
#
# Number of different labels: 36
#
# Labels: ['sweetcorn' 'peas' 'watermelon' 'tomato' 'lemon' 'jalepeno' 'carrot'
#  'paprika' 'cabbage' 'kiwi' 'cucumber' 'banana' 'apple' 'spinach' 'garlic'
#  'beetroot' 'mango' 'pomegranate' 'bell pepper' 'raddish' 'chilli pepper'
#  'eggplant' 'onion' 'potato' 'capsicum' 'cauliflower' 'ginger' 'lettuce'
#  'pear' 'corn' 'soy beans' 'sweetpotato' 'grapes' 'orange' 'turnip'
#  'pineapple']

# %%
train_df.head(5)
# Out:
#                                             Filepath       Label
# 0  C:\Users\kanchan\OneDrive\Desktop\fruit recogn...   sweetcorn
# 1  C:\Users\kanchan\OneDrive\Desktop\fruit recogn...        peas
# 2  C:\Users\kanchan\OneDrive\Desktop\fruit recogn...  watermelon
# 3  C:\Users\kanchan\OneDrive\Desktop\fruit recogn...      tomato
# 4  C:\Users\kanchan\OneDrive\Desktop\fruit recogn...       lemon

# %%
#Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 2855 validated image filenames belonging to 36 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 340 validated image filenames belonging to 36 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 340 validated image filenames belonging to 36 classes.

# %%
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(36, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/5
# C:\Users\kanchan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.3512 - loss: 2.5531 - val_accuracy: 0.8324 - val_loss: 0.5105
# Epoch 2/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.8176 - loss: 0.6041 - val_accuracy: 0.8912 - val_loss: 0.3316
# Epoch 3/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.8969 - loss: 0.3440 - val_accuracy: 0.9353 - val_loss: 0.2217
# Epoch 4/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9270 - loss: 0.2383 - val_accuracy: 0.9500 - val_loss: 0.2070
# Epoch 5/5
# ...

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)
# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred1 = [labels[k] for k in pred]
pred1
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step
# ['spinach',
#  'tomato',
#  'lemon',
#  'soy beans',
#  'cauliflower',
#  'sweetcorn',
#  'turnip',
#  'mango',
#  'cabbage',
#  'watermelon',
#  'kiwi',
#  'banana',
#  'banana',
#  'eggplant',
#  'potato',
#  'raddish',
#  'garlic',
#  'garlic',
#  'onion',
#  'onion',
#  'watermelon',
#  'jalepeno',
#  'cucumber',
#  'cauliflower',
#  'lettuce',
#  'corn',
#  'lemon',
#  'kiwi',
#  'lettuce',
#  'beetroot',
#  'turnip',
#  'turnip',
#  'watermelon',
#  'pear',
#  'soy beans',
#  'grapes',
#  'mango',
#  'kiwi',
#  'kiwi',
#  'paprika',
#  'grapes',
#  'tomato',
#  'pear',
#  'corn',
#  'kiwi',
#  'eggplant',
#  'watermelon',
#  'turnip',
#  'cabbage',
#  'grapes',
#  'eggplant',
#  'soy beans',
#  'cucumber',
#  'pineapple',
#  'potato',
#  'pineapple',
#  'grapes',
#  'sweetpotato',
#  'peas',
#  'paprika',
#  'soy beans',
#  'onion',
#  'ginger',
#  'lemon',
#  'spinach',
#  'turnip',
#  'paprika',
#  'bell pepper',
#  'pear',
# ...

# %%
def output(location):
    img=load_img(location,target_size=(224,224,3))
    img=img_to_array(img)
    img=img/255
    img=np.expand_dims(img,[0])
    answer=model.predict(img)
    y_class = answer.argmax(axis=-1)
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = labels[y]
    return res

# %%
img = output('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data/train/cabbage/Image_2.jpg')
img
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 'cabbage'

# %%
img = output('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data/train/bell pepper/Image_5.jpg')
img
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 'bell pepper'

# %%
img = output('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data/train/jalepeno/Image_4.jpg')
img
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 'jalepeno'

# %%
img = output('C:/Users/kanchan/OneDrive/Desktop/fruit recognisation/data/train/apple/Image_5.jpg')
img
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 'apple'

# %%
model.save('FV.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
